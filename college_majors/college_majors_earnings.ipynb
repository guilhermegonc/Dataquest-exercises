# %% [markdown]
# # Earnings based on College Majors

# %% [markdown]
# ## Data cleaning

# %%
import pandas as pd
# import matplotlib
# %matplotlib inline
recent_grads = pd.read_csv('recent-grads.csv')

# %%
recent_grads.head()
# Out:
#    rank  major_code                                      major    total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        men    women major_category  share_women  sample_size  employed  \
# 0   2057.0    282.0    Engineering     0.120564           36      1976
# 1    679.0     77.0    Engineering     0.101852            7       640
# 2    725.0    131.0    Engineering     0.153037            3       648
# 3   1123.0    135.0    Engineering     0.107313           16       758
# 4  21239.0  11021.0    Engineering     0.341631          289     25694
#
#        ...        part_time  full_time_year_round  unemployed  \
# ...

# %%
recent_grads.columns = ['rank', 'major_code', 'major', 'total', 'men', 'women', 'major_category',
                        'share_women', 'sample_size', 'employed', 'full_time', 'part_time', 'full_time_year_round',
                        'unemployed', 'unemployment_rate', 'median', 'p_25th', 'p_75th', 'college_jobs', 
                        'non_college_jobs', 'low_wage_jobs']

# %%
recent_grads.describe()
# Out:
#              rank   major_code          total            men          women  \
# count  172.000000   172.000000     172.000000     172.000000     172.000000
# mean    87.377907  3895.953488   39370.081395   16723.406977   22646.674419
# std     49.983181  1679.240095   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.750000  2403.750000    4549.750000    2177.500000    1778.250000
# 50%     87.500000  3608.500000   15104.000000    5434.000000    8386.500000
# 75%    130.250000  5503.250000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        share_women  sample_size      employed      full_time      part_time  \
# count   172.000000   172.000000     172.00000     172.000000     172.000000
# mean      0.522223   357.941860   31355.80814   26165.767442    8877.232558
# ...

# %%
recent_grads = recent_grads.dropna()

# %% [markdown]
# ## Link between variables

# %%
recent_grads.plot(kind='scatter',
                  x='sample_size',
                  y='median', 
                  xlim=(0, 2000), 
                  ylim=(20000, 80000),
                  title='Median x Sample size')

# %%
recent_grads.plot(kind='scatter', 
                  x='sample_size', 
                  y='unemployment_rate', 
                  xlim=(0, 1000),
                  title='Unemployment rate x Sample size')

# %%
recent_grads.plot(kind='scatter',
                  x='full_time', 
                  y='median',
                  xlim=(0, 150000),
                  ylim=(20000, 80000),
                  title='Median x Full time')

# %%
recent_grads.plot(kind='scatter',
                  x='share_women',
                  y='unemployment_rate',
                  title='Unmeployment rate x ShareWomen')

# %%
recent_grads.plot(x='men',
                  y='median',
                  kind='scatter',
                  ylim=(20000, 80000),
                  xlim=(0, 125000),
                  title='Median x Men')

# %%
recent_grads.plot(kind='scatter',
                  x='women',
                  y='median',
                  ylim=(20000, 80000),
                  xlim=(0, 125000),
                  title='Median x Women')

# %%
recent_grads.plot(kind='scatter',
                  x='total',
                  y='median',
                  ylim=(20000, 80000),
                  xlim=(0, 225000),
                  title='Median x Total')

# %%
recent_grads.plot( kind='scatter',
                  x='share_women',
                  y='median',
                  ylim=(20000, 80000),
                  title='Median x Share Women')

# %% [markdown]
# #### Do students in more popular majors make more money?
#
# Accordingly to the chart 'Median x Total' there is no link between the variables.

# %% [markdown]
# #### Do students that majored in subjects that were majority female make more money?
#
# Accordingly to the chart 'Median x Share Women', there is a tendency where the bigger the women share in major, smaller the median.

# %% [markdown]
# #### Is there any link between the number of full-time employees and median salary?
#
# Accordingly to the chart 'Median x Full Time' there is no link between the variables. Increasing full-time employes does not affect the Median sallary.

# %% [markdown]
# ## Data Distribution

# %%
recent_grads['sample_size'].plot(kind='hist', bins=50, range=(0, 1500), figsize=(15, 4), title='Sample sizes')

# %%
recent_grads['median'].plot(kind='hist', bins=25, figsize=(15, 4), range=(20000, 100000), title='Median')

# %%
recent_grads['employed'].plot(kind='hist', bins=50, figsize=(15, 4), title='Employed')

# %%
recent_grads['full_time'].plot(kind='hist', bins=25, figsize=(15, 4), title='Full time')

# %%
recent_grads['share_women'].plot(kind='hist', 
                                 bins=2, 
                                 figsize=(15, 4), 
                                 title='Share women',
                                 xticks=[0, 0.5, 1])

# %%
recent_grads.loc[recent_grads['share_women'] > 0.5, 'rank'].count() / recent_grads['rank'].count()
# Out:
# 0.5581395348837209

# %%
recent_grads['unemployment_rate'].plot(kind='hist', bins=25, figsize=(15, 4), title='Unemployment rate')

# %%
recent_grads['men'].plot(kind='hist', bins=25, range=(0, 100000), figsize=(15, 4), title='Men')

# %%
recent_grads['women'].plot(kind='hist', bins=25, range=(0, 100000), figsize=(15, 4), title='Women')

# %% [markdown]
# #### What percent of majors are predominantly male? Predominantly female
#
# 55,8% of majors are predominantly female.
#
# 44,2% of majors are predominantly male.

# %% [markdown]
# #### What's the most common median salary range?
#
# The most common sallary range is between 30,000 and 40,000

# %% [markdown]
# ## Matrixes

# %%
import pandas.plotting

# %%
pd.plotting.scatter_matrix(recent_grads[['sample_size', 'median']], 
                           figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x21008C10>,
# ...
#       dtype=object)

# %%
pd.plotting.scatter_matrix(recent_grads[['sample_size', 'median', 'unemployment_rate']], figsize=(15, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x228FC790>,
# ...
#       dtype=object)

# %% [markdown]
# ## Bar analysis

# %%
recent_grads.sort_values(['share_women'], ascending=False).head(10).plot.bar(x='major',
                               y='share_women',
                               ylim=(0, 1),
                               figsize=(15, 3),
                               title='Top 10 share women majors')

# %%
recent_grads.sort_values(['share_women'], ascending=False).tail(10).plot.bar(x='major',
                                                                             y='share_women',
                                                                             ylim=(0, 1),
                                                                             figsize=(15, 3),
                                                                             title='Bottom 10 share women majors')

# %%
recent_grads.sort_values(['unemployment_rate'], ascending=True).head(10).plot.bar(x='major',
                                                                                  y='unemployment_rate',
                                                                                  figsize=(15, 3),
                                                                                  title='Top 10 majors based on low unemployment rate')

# %%
recent_grads.sort_values(['unemployment_rate'], ascending=False).head(10).plot.bar(x='major',
                              y='unemployment_rate',
                              figsize=(15, 3),
                              title='Last 10 majors based on low unemployment rate')

# %% [markdown]
# #### Further analysis
#
# Use a grouped bar plot to compare the number of men with the number of women in each category of majors.
#
# Use a box plot to explore the distributions of median salaries and unemployment rate.
#
# Use a hexagonal bin plot to visualize the columns that had dense scatter plots from earlier in the project.
